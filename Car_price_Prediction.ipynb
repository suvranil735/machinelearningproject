# %%
import pandas as pd

# %%
df = pd.read_csv("D://Arghya_IMI_28092022//IMI_Courses_2024\Data Analytics and Machine Learning//1. Course Materials//Session 11-12 (Regression)//CarPrice_Assignment.csv")

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df1 = df[['symboling','fueltype','doornumber','enginetype','enginesize','horsepower','compressionratio','highwaympg','price']]

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df1.head()
# Out:
#    symboling fueltype doornumber enginetype  enginesize  horsepower  \
# 0          3      gas        two       dohc         130         111
# 1          3      gas        two       dohc         130         111
# 2          1      gas        two       ohcv         152         154
# 3          2      gas       four        ohc         109         102
# 4          2      gas       four        ohc         136         115
#
#    compressionratio  highwaympg    price
# 0               9.0          27  13495.0
# 1               9.0          27  16500.0
# 2               9.0          26  16500.0
# 3              10.0          30  13950.0
# 4               8.0          22  17450.0

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df1['fueltype']=le.fit_transform(df1['fueltype'])
# Out:
# C:\Users\Arghya\AppData\Local\Temp\ipykernel_11248\752117416.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['fueltype']=le.fit_transform(df1['fueltype'])

# %%
df1.head(2)
# Out:
#    symboling  fueltype doornumber enginetype  enginesize  horsepower  \
# 0          3         1        two       dohc         130         111
# 1          3         1        two       dohc         130         111
#
#    compressionratio  highwaympg    price
# 0               9.0          27  13495.0
# 1               9.0          27  16500.0

# %%
df1['doornumber']=le.fit_transform(df1['doornumber'])
df1['enginetype']=le.fit_transform(df1['enginetype'])
# Out:
# C:\Users\Arghya\AppData\Local\Temp\ipykernel_11248\2436034435.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['doornumber']=le.fit_transform(df1['doornumber'])
# C:\Users\Arghya\AppData\Local\Temp\ipykernel_11248\2436034435.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['enginetype']=le.fit_transform(df1['enginetype'])

# %%
df1.head(2)
# Out:
#    symboling  fueltype  doornumber  enginetype  enginesize  horsepower  \
# 0          3         1           1           0         130         111
# 1          3         1           1           0         130         111
#
#    compressionratio  highwaympg    price
# 0               9.0          27  13495.0
# 1               9.0          27  16500.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
cols=['enginesize','horsepower','highwaympg']

# %%
df1[cols]=ss.fit_transform(df1[cols])
# Out:
# C:\Users\Arghya\AppData\Local\Temp\ipykernel_11248\1276593649.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[cols]=ss.fit_transform(df1[cols])

# %%
df1.head(2)
# Out:
#    symboling  fueltype  doornumber  enginetype  enginesize  horsepower  \
# 0          3         1           1           0    0.074449    0.174483
# 1          3         1           1           0    0.074449    0.174483
#
#    compressionratio  highwaympg    price
# 0               9.0   -0.546059  13495.0
# 1               9.0   -0.546059  16500.0

# %%
#df1['enginesize']=ss.fit_transform(df1[['enginesize']])

# %%
from sklearn.model_selection import train_test_split

# %%
df1.columns
# Out:
# Index(['symboling', 'fueltype', 'doornumber', 'enginetype', 'enginesize',
#        'horsepower', 'compressionratio', 'highwaympg', 'price'],
#       dtype='object')

# %%
X = df1[['symboling', 'fueltype', 'doornumber', 'enginetype', 'enginesize','horsepower', 'compressionratio', 'highwaympg']]
Y = df1['price']

# %%
X.shape
# Out:
# (205, 8)

# %%
X_train, X_test, Y_train,Y_test = train_test_split(X, Y, test_size=0.3)

# %%
X_train.shape
# Out:
# (143, 8)

# %%
X_test.shape
# Out:
# (62, 8)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt = DecisionTreeRegressor()

# %%
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = dt.predict(X_test)

# %%
y_pred
# Out:
# array([ 8921.        , 12439.        , 10595.        , 12945.        ,
#         9370.        , 15591.66666667,  6843.33333333, 11248.        ,
#         7045.        , 19045.        , 40960.        ,  5572.        ,
#        29924.        ,  8495.        , 10787.5       , 19045.        ,
#        14535.        , 12145.        ,  8495.        ,  8068.        ,
#         8495.        , 11248.        ,  6445.        , 31400.5       ,
#         8358.        , 13949.        , 10795.        , 15998.        ,
#        16695.        ,  5572.        ,  5572.        ,  6338.        ,
#         7295.        , 17710.        , 16503.        ,  8148.        ,
#         8778.        ,  8358.        , 34778.        , 40960.        ,
#        18150.        , 12439.        , 15591.66666667,  8148.        ,
#        21105.        ,  7738.        , 40960.        , 15998.        ,
#         6479.        , 40960.        ,  6843.33333333, 15591.66666667,
# ...

# %%
Y_test
# Out:
# 28      8921.000
# 168     9639.000
# 59      8845.000
# 149    11694.000
# 64     11245.000
#          ...
# 130     9295.000
# 82     12629.000
# 9      17859.167
# 139     7053.000
# 47     32250.000
# Name: price, Length: 62, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(Y_test,y_pred)
# Out:
# 1578.5833279569893

# %%
mean_squared_error(Y_test,y_pred)
# Out:
# 5409917.6876433715

# %%
dt.feature_importances_
# Out:
# array([7.33989491e-03, 1.99275731e-04, 6.07914064e-03, 4.99843800e-04,
#        6.53717021e-01, 6.09857646e-02, 2.13788065e-02, 2.49800253e-01])

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()

# %%
rf.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred_rf = rf.predict(X_test)

# %%
mean_absolute_error(Y_test,y_pred_rf)
# Out:
# 1487.034826292883

# %%
mean_squared_error(Y_test,y_pred_rf)
# Out:
# 4315478.5348467985

# %%
X_train.columns
# Out:
# Index(['symboling', 'fueltype', 'doornumber', 'enginetype', 'enginesize',
#        'horsepower', 'compressionratio', 'highwaympg'],
#       dtype='object')

# %%
new_data = pd.read_csv("D://Arghya_IMI_28092022//IMI_Courses_2024//Data Analytics and Machine Learning//1. Course Materials//Session 11-12 (Regression)//New_car_pred.csv")

# %%
new_data
# Out:
#    symboling  fueltype  doornumber  enginetype  enginesize  horsepower  \
# 0          3         2           2           2         112         110
#
#    compressionratio  highwaympg
# 0                11          10

# %%
rf.predict(new_data)
# Out:
# array([31240.57166667])
